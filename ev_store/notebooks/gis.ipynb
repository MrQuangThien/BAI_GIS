# %%
import os
import sys
import django


base_dir = r"E:\new2025\BAIGIS" 


notebooks_dir = os.getcwd()
project_root = os.path.dirname(notebooks_dir)  

sys.path.insert(0, project_root)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "ev_store.settings")

django.setup()
print("Thành công!")
# Out:
# Thành công!

# %%
from core.models import TramSac

# %%
# Trong cell của notebook
import asyncio
from asgiref.sync import sync_to_async
from core.models import TramSac

# Tạo hàm async wrapper
async def create_tram():
    await sync_to_async(TramSac.objects.create)(
        ten_tram="Trạm sạc thử nghiệm Quận 7",
        dia_chi="Công viên Phú Mỹ Hưng, Quận 7, TP.HCM",
        cong_suat=120,
        loai_sac="DC 150kW",
        trang_thai=True,
        lat=10.7300,
        lon=106.7000
    )
    print("Đã tạo trạm sạc thành công!")

# Chạy hàm async
await create_tram()
# Out:
# Đã tạo trạm sạc thành công!

# %%
# Trong cell của notebook
from asgiref.sync import sync_to_async
from core.models import TramSac

# Tạo nhiều trạm sạc ở Quận Gò Vấp
async def create_tram_go_vap():
    data = [
        {
            "ten_tram": "Trạm sạc Công viên Gia Định",
            "dia_chi": "Công viên Gia Định, Quận Gò Vấp, TP.HCM",
            "cong_suat": 60,
            "loai_sac": "AC",
            "lat": 10.8129,
            "lon": 106.6763,
        },
        {
            "ten_tram": "Trạm sạc Nguyễn Văn Khối",
            "dia_chi": "Nguyễn Văn Khối, Phường 11, Quận Gò Vấp, TP.HCM",
            "cong_suat": 120,
            "loai_sac": "DC 120kW",
            "lat": 10.8331,
            "lon": 106.6665,
        },
        {
            "ten_tram": "Trạm sạc Phan Văn Trị",
            "dia_chi": "Phan Văn Trị, Phường 7, Quận Gò Vấp, TP.HCM",
            "cong_suat": 150,
            "loai_sac": "DC 150kW",
            "lat": 10.8267,
            "lon": 106.6893,
        },
        {
            "ten_tram": "Trạm sạc Lotte Mart Gò Vấp",
            "dia_chi": "Lotte Mart Gò Vấp, Quận Gò Vấp, TP.HCM",
            "cong_suat": 100,
            "loai_sac": "DC",
            "lat": 10.8195,
            "lon": 106.6906,
        },
        {
        "ten_tram": "Vincom Center Đồng Khởi",
        "dia_chi": "72 Lê Thánh Tôn, Bến Nghé, Quận 1, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW, AC 11kW",
        "lat": 10.7769,
        "lon": 106.7018
    },
    {
        "ten_tram": "Vinhomes Golden River",
        "dia_chi": "02 Tôn Đức Thắng, Bến Nghé, Quận 1, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7853,
        "lon": 106.7095
    },
    {
        "ten_tram": "EV ONE - Audi Hồ Chí Minh",
        "dia_chi": "6B Tôn Đức Thắng, Bến Nghé, Quận 1, TP.HCM",
        "cong_suat": 180,
        "loai_sac": "DC 180kW, AC 11kW",
        "lat": 10.7842,
        "lon": 106.7077
    },
    {
        "ten_tram": "EV ONE - Deutsches Haus",
        "dia_chi": "33 Lê Duẩn, Bến Nghé, Quận 1, TP.HCM",
        "cong_suat": 22,
        "loai_sac": "AC 22kW",
        "lat": 10.7811,
        "lon": 106.6989
    },
    {
        "ten_tram": "Vinhomes Central Park (Landmark 81)",
        "dia_chi": "208 Nguyễn Hữu Cảnh, Phường 22, Bình Thạnh, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW, AC 11kW",
        "lat": 10.7951,
        "lon": 106.7218
    },
    {
        "ten_tram": "Vincom Plaza Phan Văn Trị",
        "dia_chi": "12 Phan Văn Trị, Phường 7, Gò Vấp, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.8268,
        "lon": 106.6931
    },
    {
        "ten_tram": "Vincom Plaza Quang Trung",
        "dia_chi": "190 Quang Trung, Phường 10, Gò Vấp, TP.HCM",
        "cong_suat": 30,
        "loai_sac": "DC 30kW",
        "lat": 10.8285,
        "lon": 106.6806
    },
    {
        "ten_tram": "Chung cư Hà Đô Z751",
        "dia_chi": "18 Phan Văn Trị, Phường 10, Gò Vấp, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.8277,
        "lon": 106.6780
    },
    {
        "ten_tram": "Vincom Plaza Cộng Hòa",
        "dia_chi": "15-17 Cộng Hòa, Phường 4, Tân Bình, TP.HCM",
        "cong_suat": 250,
        "loai_sac": "DC 250kW, DC 60kW",
        "lat": 10.7997,
        "lon": 106.6624
    },
    {
        "ten_tram": "Chung cư Republic Plaza",
        "dia_chi": "18E Cộng Hòa, Phường 4, Tân Bình, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.8005,
        "lon": 106.6618
    },
    {
        "ten_tram": "EV ONE - Etown 6",
        "dia_chi": "364 Cộng Hòa, Phường 13, Tân Bình, TP.HCM",
        "cong_suat": 22,
        "loai_sac": "AC 22kW",
        "lat": 10.8066,
        "lon": 106.6432
    },
    {
        "ten_tram": "Đại lý VinFast Đông Sài Gòn",
        "dia_chi": "682A Trường Chinh, Phường 15, Tân Bình, TP.HCM",
        "cong_suat": 120,
        "loai_sac": "DC 120kW, DC 60kW",
        "lat": 10.8164,
        "lon": 106.6321
    },
    {
        "ten_tram": "EV ONE - Mường Thanh Sài Gòn",
        "dia_chi": "261C Nguyễn Văn Trỗi, Phường 10, Phú Nhuận, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.7983,
        "lon": 106.6715
    },
    {
        "ten_tram": "Porsche Centre Saigon",
        "dia_chi": "Lô VII-1, Khu chế xuất Tân Thuận, Quận 7, TP.HCM",
        "cong_suat": 350,
        "loai_sac": "DC 350kW, AC 22kW",
        "lat": 10.7672,
        "lon": 106.7419
    },
    {
        "ten_tram": "Showroom Audi City Phú Mỹ Hưng",
        "dia_chi": "Đường Nguyễn Văn Linh, Phường Tân Phong, Quận 7, TP.HCM",
        "cong_suat": 160,
        "loai_sac": "DC 160kW, AC 22kW",
        "lat": 10.7298,
        "lon": 106.7092
    },
    {
        "ten_tram": "VinFast - Chung cư Golden King",
        "dia_chi": "15 Nguyễn Lương Bằng, Phường Tân Phú, Quận 7, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7291,
        "lon": 106.7208
    },
    {
        "ten_tram": "VinFast - VinCom+ Nam Long",
        "dia_chi": "71 Trần Trọng Cung, Phường Tân Thuận Đông, Quận 7, TP.HCM",
        "cong_suat": 30,
        "loai_sac": "DC 30kW",
        "lat": 10.7423,
        "lon": 106.7327
    },
    {
        "ten_tram": "Vincom Plaza Lê Văn Việt",
        "dia_chi": "50 Lê Văn Việt, Hiệp Phú, TP. Thủ Đức, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.8465,
        "lon": 106.7764
    },
    {
        "ten_tram": "Vinhomes Grand Park (Tòa S1)",
        "dia_chi": "Nguyễn Xiển, Long Thạnh Mỹ, TP. Thủ Đức, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.8398,
        "lon": 106.8365
    },
    {
        "ten_tram": "Chung cư Sky 9",
        "dia_chi": "61 Đường số 1, Phú Hữu, TP. Thủ Đức, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7972,
        "lon": 106.7901
    },
    {
        "ten_tram": "Cửa hàng xăng dầu PVOIL Phú Hữu",
        "dia_chi": "868 Nguyễn Duy Trinh, Phú Hữu, TP. Thủ Đức, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.7935,
        "lon": 106.7948
    },
    {
        "ten_tram": "Cửa hàng xăng dầu số 2 (Phạm Văn Đồng)",
        "dia_chi": "778 Phạm Văn Đồng, Hiệp Bình Chánh, TP. Thủ Đức, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.8282,
        "lon": 106.7214
    },
    {
        "ten_tram": "Đại lý Ô tô VinFast An Thái",
        "dia_chi": "464 Kinh Dương Vương, An Lạc A, Bình Tân, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.7408,
        "lon": 106.6215
    },
    {
        "ten_tram": "Chung cư Thái Sơn Nhất Lan 3",
        "dia_chi": "QL1A, Phường Tân Tạo, Bình Tân, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7554,
        "lon": 106.5982
    },
    {
        "ten_tram": "Chung cư Summer Square",
        "dia_chi": "243 Tân Hòa Đông, Phường 14, Quận 6, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7592,
        "lon": 106.6345
    },
    {
        "ten_tram": "EV ONE - Hyundai Trường Chinh",
        "dia_chi": "2450 QL1A, Trung Mỹ Tây, Quận 12, TP.HCM",
        "cong_suat": 22,
        "loai_sac": "AC 22kW",
        "lat": 10.8491,
        "lon": 106.6118
    },
    {
        "ten_tram": "VinFast - Bãi đỗ xe Thanh Phong Auto",
        "dia_chi": "1260 Lê Văn Lương, Phước Kiển, Nhà Bè, TP.HCM",
        "cong_suat": 30,
        "loai_sac": "DC 30kW",
        "lat": 10.7065,
        "lon": 106.7029
    },
    {
        "ten_tram": "Chung cư HAGL Gold House",
        "dia_chi": "187A Lê Văn Lương, Phước Kiển, Nhà Bè, TP.HCM",
        "cong_suat": 11,
        "loai_sac": "AC 11kW",
        "lat": 10.7203,
        "lon": 106.7042
    },
    {
        "ten_tram": "VinFast - Đại lý Chevrolet Phú Mỹ Hưng",
        "dia_chi": "1489 Nguyễn Văn Linh, Tân Phong, Quận 7, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.7285,
        "lon": 106.7118
    },
    {
        "ten_tram": "Vincom Plaza Thủ Đức",
        "dia_chi": "216 Võ Văn Ngân, Bình Thọ, TP. Thủ Đức, TP.HCM",
        "cong_suat": 30,
        "loai_sac": "DC 30kW",
        "lat": 10.8504,
        "lon": 106.7716
    }

, {
        "ten_tram": "Cửa hàng xăng dầu PVOIL Hiệp Bình Chánh",
        "dia_chi": "180 Phạm Văn Đồng, Hiệp Bình Chánh, TP. Thủ Đức, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.8280,
        "lon": 106.7235
}, {
        "ten_tram": "Chung cư The EastGate",
        "dia_chi": "273 Lê Văn Việt, Tăng Nhơn Phú A, TP. Thủ Đức, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "AC 60kW",
        "lat": 10.8473,
        "lon": 106.7778 
}, {
        "ten_tram": "Cửa hàng xăng dầu PVOIL Tân Sơn Nhất",
        "dia_chi": "Số 1 Đường số 17, Phường 4, Tân Bình, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.8033,
        "lon": 106.6532
        },
        {
        "ten_tram": "Cửa hàng xăng dầu PVOIL Bình Trị Đông",
        "dia_chi": "Lô 7-8 Đường số 7, Phường Bình Trị Đông B, Bình Tân, TP.HCM",
        "cong_suat": 60,
        "loai_sac": "DC 60kW",
        "lat": 10.7475,
        "lon": 106.6089
        }
    ]

    for tram in data:
        await sync_to_async(TramSac.objects.create)(
            ten_tram=tram["ten_tram"],
            dia_chi=tram["dia_chi"],
            cong_suat=tram["cong_suat"],
            loai_sac=tram["loai_sac"],
            trang_thai=True,
            lat=tram["lat"],
            lon=tram["lon"],
        )

    print("Đã tạo xong các trạm sạc Quận Gò Vấp")

# Chạy trong notebook
await create_tram_go_vap()
# Out:
# Đã tạo xong các trạm sạc Quận Gò Vấp
